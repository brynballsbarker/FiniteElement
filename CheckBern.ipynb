# %%
import numpy as np
import matplotlib.pyplot as plt
from math import factorial as ft

# %%
x = np.linspace(0,1,100)

# %%
num_el = 3

# %%
p = 2

# %%
B = []

for e in range(num_el):
    for a in range(1,p+2):
        com = ft(p)/(ft(a-1)*ft(p+1-a))
        bern = lambda x, a=a, com=com: 1/2**p * com * (1-x)**(p-a+1)*(1+x)**(a-1)
        B.append(bern)

# %%
for e in range(num_el):

# %%
dom = np.linspace(-1,1,100)
for bern in B:
    plt.plot(dom,bern(dom))
plt.show()

# %%
bigC = np.array([[1,0,0,0,0,0,0],[0,1,.5,0,0,0,0],[0,0,.5,1,.5,0,0],
                 [0,0,0,0,.5,0,1],[0,0,0,0,0,0,1]])

# %%
N_vals = []
for N in range(5):
    vals = []
    for xval in dom:
        res = sum(bigC[N][i]*B[i](xval) for i in range(7))
        vals.append(res)
    plt.plot(dom,vals)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-9e557d230428> in <module>
#       3     vals = []
#       4     for xval in dom:
# ----> 5         res = sum(bigC[N][i]*B[i](xval) for i in range(7))
#       6         vals.append(res)
#       7     plt.plot(dom,vals)
#
# <ipython-input-49-9e557d230428> in <genexpr>(.0)
#       3     vals = []
#       4     for xval in dom:
# ----> 5         res = sum(bigC[N][i]*B[i](xval) for i in range(7))
#       6         vals.append(res)
#       7     plt.plot(dom,vals)
#
# IndexError: list index out of range

# %%
C1 = np.array([[1,0,0],[0,1,.5],[0,0,.5]])
C2 = np.array([[.5,0,0],[.5,1,.5],[0,0,.5]])
C3 = np.array([[.5,0,0],[.5,1,0],[0,0,1]])
C= [C1,C2,C3]

# %%
C
# Out:
# [array([[1. , 0. , 0. ],
#         [0. , 1. , 0.5],
#         [0. , 0. , 0.5]]), array([[0.5, 0. , 0. ],
#         [0.5, 1. , 0.5],
#         [0. , 0. , 0.5]]), array([[0.5, 0. , 0. ],
#         [0.5, 1. , 0. ],
#         [0. , 0. , 1. ]])]

# %%
for i in range(3):
    for j in range(3):
        N1 = lambda x: C[i][j][0]*B[0](x)+C[i][j][2]*B[0](x)+C[i][j][2]*B[2](x)
        plt.plot(dom+2*i,N1(dom),label=j)
    plt.legend()
plt.show()
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
cpts = 4
icount = 0
t = 0
step = 1/(cpts-1)

for i in range(cpts):
    if (1-t < 5e-6): t = 1
    jcount = 0
    p.append(0)
    p.append(0)
    for j in range(npts):
        bern
